# %% [markdown]
# <a href="https://colab.research.google.com/github/tanu268/crop-disease-detection/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# seeding for reproducibility

# %%
#sets seeds for reproducibility
import random
random.seed(0)

import numpy as np
np.random.seed(0)

import tensorflow as tf
tf.random.set_seed(0)

# %% [markdown]
# importing the dependencies

# %%
import os
import json
from zipfile import ZipFile
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# %% [markdown]
# data curation

# %%
#upload the kaggle.json file
# !pip install kaggle

# %%
kaggle_credentails = json.load(open('/content/kaggle.json'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-7c4dc8430cdb> in <cell line: 0>()
# ----> 1 kaggle_credentails = json.load(open('/content/kaggle.json'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/kaggle.json'

# %%
#setupvKaggle API key as environment variables
os.environ['KAGGLE_USERNAME'] = kaggle_credentails['username']
os.environ['KAGGLE_KEY'] = kaggle_credentails['key']

# %%
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset
# License(s): CC-BY-NC-SA-4.0

# %%
# !ls
# Out:
# kaggle.json  plantvillage-dataset.zip  sample_data

# %%
with ZipFile('/content/plantvillage-dataset.zip', 'r') as zipObj:
  zipObj.extractall()

# %%
print(os.listdir('plantvillage dataset/segmented'))

print(len(os.listdir('plantvillage dataset/segmented')))
print(os.listdir('plantvillage dataset/segmented')[:5]) #Apply slicing to the result of os.listdir()

print(len(os.listdir('plantvillage dataset/color')))
print(os.listdir('plantvillage dataset/color')[:5]) #Apply slicing to the result of os.listdir()

print(len(os.listdir('plantvillage dataset/grayscale')))
print(os.listdir('plantvillage dataset/grayscale')[:5]) #Apply slicing to the result of os.listdir()
# Out:
# ['Grape___Esca_(Black_Measles)', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Grape___Black_rot', 'Tomato___Bacterial_spot', 'Corn_(maize)___healthy', 'Strawberry___healthy', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Cherry_(including_sour)___healthy', 'Tomato___healthy', 'Tomato___Early_blight', 'Tomato___Tomato_mosaic_virus', 'Apple___Apple_scab', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Common_rust_', 'Tomato___Late_blight', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Blueberry___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___healthy', 'Potato___healthy', 'Apple___healthy', 'Strawberry___Leaf_scorch', 'Orange___Haunglongbing_(Citrus_greening)', 'Squash___Powdery_mildew', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Pepper,_bell___healthy', 'Tomato___Leaf_Mold', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Peach___Bacterial_spot', 'Soybean___healthy', 'Pepper,_bell___Bacterial_spot', 'Grape___healthy', 'Potato___Late_blight', 'Raspberry___he
# ...

# %%
print(len(os.listdir('plantvillage dataset/color/Grape___healthy')))
print((os.listdir('plantvillage dataset/color/Grape___healthy')[:5]))
# Out:
# 423
# ['c197dfe9-44d6-4a7e-bb5a-75e2bf05380b___Mt.N.V_HL 6100.JPG', '9ceba66a-d7b0-4ed4-98c3-37d361517a90___Mt.N.V_HL 6147.JPG', 'c05f4201-5ab9-4bbd-b19e-c36515b7b3a9___Mt.N.V_HL 6134.JPG', '41506a32-a472-4ca3-a8e0-4980c179096b___Mt.N.V_HL 6206.JPG', 'e4dc54f7-46a2-47d4-889c-477883df2767___Mt.N.V_HL 9079.JPG']

# %% [markdown]
# Data preprocessing

# %%
#Dataset path
base_dir = 'plantvillage dataset/color'

# %%
import matplotlib.image as mpimg
import os

base_dir = "/content/plantvillage dataset/color/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"  # Path to the directory

# Get a list of image files in the directory
image_files = [f for f in os.listdir(base_dir) if os.path.isfile(os.path.join(base_dir, f))]

# Select the first image file (you can modify this to select a specific image)
image_path = os.path.join(base_dir, image_files[0])

# Read the image
img = mpimg.imread(image_path)

print(img.shape)
# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis number
plt.show()
# Out:
# (256, 256, 3)

# %%
import matplotlib.image as mpimg
import os

base_dir = "/content/plantvillage dataset/color/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"  # Path to the directory


# Read the image using the image_path
img = mpimg.imread(image_path) #Read the image using the image_path instead of image_dir

print(img)
# Out:
# [[[107 103 117]
#   [107 103 117]
#   [106 102 116]
#   ...
#   [ 79  74  80]
#   [ 77  74  81]
#   [ 76  75  83]]
#
#  [[107 103 117]
#   [107 103 117]
#   [107 103 117]
#   ...
#   [ 80  75  81]
#   [ 78  75  82]
#   [ 78  77  85]]
#
#  [[108 104 118]
#   [108 104 118]
#   [107 103 117]
#   ...
#   [ 81  76  82]
#   [ 80  77  84]
#   [ 79  78  86]]
#
#  ...
#
#  [[209 200 195]
#   [217 207 205]
#   [223 213 212]
#   ...
#   [147 142 149]
#   [147 142 149]
#   [146 141 148]]
#
#  [[194 183 179]
#   [204 193 191]
#   [213 201 201]
#   ...
#   [148 143 150]
#   [148 143 150]
#   [148 143 150]]
#
#  [[177 166 162]
#   [189 178 176]
#   [199 187 187]
#   ...
#   [149 144 151]
#   [150 145 152]
#   [150 145 152]]]

# %%
#Image parameters
img_size = 224
batch_size = 32

# %% [markdown]
# Train Test Split

# %%
#Imagee Data Generators
data_gen = ImageDataGenerator(rescale=1/255,
                              validation_split=0.2
)  #Use 20% of data for validation

# %%
#Train Generator
train_generator = data_gen.flow_from_directory(base_dir,
                                               target_size=(img_size, img_size),
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                               subset='training'
)
# Out:
# Found 0 images belonging to 0 classes.

# %%
# Validation Generator
validation_generator = data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 0 classes.

# %% [markdown]
# Convolutional Neural Network

# %%
# Model Definition
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)))
model.add(layers.MaxPooling2D(2, 2))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))


model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(train_generator.num_classes, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 186624)         │             0 │
# ...

# %%
# Compile the Model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Model training

# %%
# Training the Model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,  # Number of steps per epoch
    epochs=5,  # Number of epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size  # Validation steps
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 110s 76ms/step - accuracy: 0.6071 - loss: 1.6152 - val_accuracy: 0.8509 - val_loss: 0.4787
# Epoch 2/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 97s 71ms/step - accuracy: 0.9227 - loss: 0.2457 - val_accuracy: 0.8640 - val_loss: 0.4544
# Epoch 3/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 96s 71ms/step - accuracy: 0.9705 - loss: 0.0949 - val_accuracy: 0.8882 - val_loss: 0.4046
# Epoch 4/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 97s 71ms/step - accuracy: 0.9773 - loss: 0.0679 - val_accuracy: 0.8632 - val_loss: 0.5822
# Epoch 5/5
# ...

# %%
# Model Evaluation
print("Evaluating model...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.8769 - loss: 0.5662
# Validation Accuracy: 87.91%

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Building a Predictive System

# %%
# Function to Load and Preprocess the Image using Pillow
def load_and_preprocess_image(image_dir, target_size=(224, 224)):
    # Load the image
    img = Image.open(image_dir)
    # Resize the image
    img = img.resize(target_size)
    # Convert the image to a numpy array
    img_array = np.array(img)
    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    # Scale the image values to [0, 1]
    img_array = img_array.astype('float32') / 255.
    return img_array

# Function to Predict the Class of an Image
def predict_image_class(model, image_dir, class_indices):
    preprocessed_img = load_and_preprocess_image(image_dir)
    predictions = model.predict(preprocessed_img)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_indices[predicted_class_index]
    return predicted_class_name

# %%
# Create a mapping from class indices to class names
class_indices = {v: k for k, v in train_generator.class_indices.items()}

# %%
class_indices
# Out:
# {0: 'Apple___Apple_scab',
#  1: 'Apple___Black_rot',
#  2: 'Apple___Cedar_apple_rust',
#  3: 'Apple___healthy',
#  4: 'Blueberry___healthy',
#  5: 'Cherry_(including_sour)___Powdery_mildew',
#  6: 'Cherry_(including_sour)___healthy',
#  7: 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  8: 'Corn_(maize)___Common_rust_',
#  9: 'Corn_(maize)___Northern_Leaf_Blight',
#  10: 'Corn_(maize)___healthy',
#  11: 'Grape___Black_rot',
#  12: 'Grape___Esca_(Black_Measles)',
#  13: 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  14: 'Grape___healthy',
#  15: 'Orange___Haunglongbing_(Citrus_greening)',
#  16: 'Peach___Bacterial_spot',
#  17: 'Peach___healthy',
#  18: 'Pepper,_bell___Bacterial_spot',
#  19: 'Pepper,_bell___healthy',
#  20: 'Potato___Early_blight',
#  21: 'Potato___Late_blight',
#  22: 'Potato___healthy',
#  23: 'Raspberry___healthy',
#  24: 'Soybean___healthy',
#  25: 'Squash___Powdery_mildew',
#  26: 'Strawberry___Leaf_scorch',
#  27: 'Strawberry___healthy',
# ...

# %%
# saving the class names as json file
json.dump(class_indices, open('class_indices.json', 'w'))

# %%
# Example Usage
image_path = '/content/Apple___Black_rot.jpeg'
#image_path = '/content/test_blueberry_healthy.jpg'
#image_path = '/content/test_potato_early_blight.jpg'
predicted_class_name = predict_image_class(model, image_path, class_indices)

# Output the result
print("Predicted Class Name:", predicted_class_name)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Predicted Class Name: Cherry_(including_sour)___Powdery_mildew

# %%
model.save('https://drive.google.com/drive/folders/1qVCw-sNUe4QF3aTb_-2a6ZJK6_cH7aJc?usp=drive_link_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ed2c2c222aac> in <cell line: 0>()
# ----> 1 model.save('https://drive.google.com/drive/folders/1qVCw-sNUe4QF3aTb_-2a6ZJK6_cH7aJc?usp=drive_link_model.h5')
#
# NameError: name 'model' is not defined

# %%
model.save('model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-596723284980> in <cell line: 0>()
# ----> 1 model.save('model.h5')
#
# NameError: name 'model' is not defined
